# %%
import os
from dotenv import load_dotenv 
load_dotenv()
os.environ["TAVILY_API_KEY"] = os.getenv("TAVILY_API_KEY")
from langchain_groq import ChatGroq
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=5,
    topic="general",
)
tavily_search_tool.invoke("Current news about AI")
# Out:
# {'query': 'Current news about AI',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.artificialintelligence-news.com/',
#    'title': 'AI News | Latest News | Insights Powering AI-Driven Business Growth',
#    'content': 'AI News delivers the latest updates in artificial intelligence, machine learning, deep learning, enterprise AI, and emerging tech worldwide.',
#    'score': 0.998103,
#    'raw_content': None},
#   {'url': 'https://www.reuters.com/technology/artificial-intelligence/',
#    'title': 'AI News | Latest Headlines and Developments | Reuters',
#    'content': 'Explore the latest artificial intelligence news with Reuters - from AI breakthroughs and technology trends to regulation, ethics, business and global',
#    'score': 0.99589807,
#    'raw_content': None},
#   {'url': 'https://www.nbcnews.com/artificial-intelligence',
#    'title': 'Artificial intelligence - NBC News',
#    'content': "The latest news and top stories on artificial intelligence, including AI chatbots like Microsoft's ChatGPT, Apple's AI Chatbot and Google's Bard.",
#    'score': 0.9946568,
#    'raw_content': None},
#   {'url': 'https://www.wsj.com/tech/ai?gaa_at=eafs&gaa_n=AWEtsqfJyqa5Xi9UpDlx2i8YlDTlJgxG3usgktvBN0RSi1Kd7CgRFICIoIEJ&gaa_ts=699de29f&gaa_sig=l_8_-9itd8ZQy_51Se0rA33yN3eyF0gR26ndF7T82aTvbSxFzJrz5Uc0ZQkBUC0J_vjsBmnRgpXr2dEkKE02UQ%3D%3D',
#    'title': 'Artificial Intelligence - Latest AI News and Analysis - WSJ.com',
#    'content': "Meta and AMD Agree to AI Chips Deal Worth More Than $100 Billion · The deal could result in Meta owning as much as 10% of AMD's stock as the chipmaker seeks to",
#    'score': 0.99304235,
#    'raw_content': None},
#   {'url': 'https://openai.com/news/',
#    'title': 'OpenAI News',
#    'content': 'Stay up to speed on the rapid advancement of AI technology and the benefits it offers to humanity.',
#    'score': 0.9890131,
#    'raw_content': None}],
#  'response_time': 0.65,
#  'request_id': '7532af68-ceda-48ca-94b4-3ac423ee14be'}

# %%
from langchain.tools import tool

@tool("calculator", description="Performs arithmetic calculations. Use this for any math problems.")
def calc(expression: str) -> str:
    """Evaluate mathematical expressions."""
    return str(eval(expression))

# %%
from langchain.agents import create_agent
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=5,
    topic="general",
)
tavily_search_tool.invoke("Current news about AI")
from langchain.tools import tool

@tool("calculator", description="Performs arithmetic calculations. Use this for any math problems.")
def calc(expression: str) -> str:
    """Evaluate mathematical expressions."""
    return str(eval(expression))

from langchain_groq import ChatGroq
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = ChatGroq(model="llama-3.3-70b-versatile")

agent = create_agent(
    model=model,
    tools=[tavily_search_tool, calc], 
)
user_input = "What is the current news about AI and what is 123 * 456?"

for step in agent.stream(
    {'messages': user_input},
    stream_mode='values'
):
    step['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the current news about AI and what is 123 * 456?
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (dye5yyhth)
#  Call ID: dye5yyhth
#   Args:
#     query: current news about AI
#     search_depth: advanced
#     topic: news
#   calculator (jxq2675pd)
#  Call ID: jxq2675pd
#   Args:
#     expression: 123 * 456
# ================================= Tool Message =================================
# Name: calculator
#
# 56088
# ================================== Ai Message ==================================
#
# The current news about AI includes advancements in personal intelligence, AI tools in Gmail and Chrome, and new learning tools for students. Additionally, there are trends in AI and data science for 2026, including the growth of the "factory" infrastructure for all-in AI adapters, a greater focus on generative AI as an organizational resource, and continued progression toward value from agentic AI.
#
# The result of the calculation 123 * 456 is 56088.
